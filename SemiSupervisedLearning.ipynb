# %% [markdown]
# # Simulating semi-supervised on image classification

# %% [markdown]
# ## Prerequisite
# You are going to train image classification using Cifar10.<br>
# Assume you only have a part of the dataset labeled, while you have a plenty of unlabeled data.<br><br>
# Initially you only have 10000 images, with labels.<br>
# In this situation, you start the model training with the only dataset you have, and retrain gradually by adding data.<br>
# There are three strategies for adding data:
# 1. Semi-supervised learning: make inference on unlabeled data and add those with high probability as labeled training data.
# 2. Active learning: add those with high importance as labeled training data, and a human has to label them.
# 3. Combination of both
#
# ## Trying for 1. Semi-supervised learning

# %% [markdown]
# ## This notebook simulates semi-supervised learning using Cifar10 CNN

# %% [markdown]
# ### Train a base model

# %%
# set Keras backend to Tensorflow
import os
os.environ["KERAS_BACKEND"] = "tensorflow"
kerasBKED = os.environ["KERAS_BACKEND"] 
print(kerasBKED)
# Out:
# tensorflow

# %%
# import
import keras
from keras.models import load_model
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, InputLayer
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.model_selection import train_test_split
import os
import pickle
import numpy as np
# Out:
# Using TensorFlow backend.
# /opt/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
# make saving directory
saveDir = "./cifar10/semi/"
if not os.path.isdir(saveDir):
    os.makedirs(saveDir)

# %% [markdown]
# ## load Cifar10 images and divide them to inititial, first, second and third sets.
# Assuming to train a Cifar10 CNN model with data increasing gradually, I get the following datasets:
# - initial training set: 10000 images
# - unlabeled training set: 40000 images
# - test set: 10000 images

# %%
# get Cifar10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

print('x train shape:', x_train.shape)
print(x_train.shape[0], 'training images')
print(x_test.shape[0], 'test images')
# Out:
# x train shape: (50000, 32, 32, 3)
# 50000 training images
# 10000 test images

# %%
# prerequisite
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# %%
initNum = 10000
x_train1 = x_train[:initNum]
y_train1 = y_train[:initNum]
remainXTrain = x_train[initNum:]
remainYTrain = y_train[initNum:]

# %%
print("initial training X: {0}\n\
initial training Y: {1}\n\
remaining training X: {2}\n\
remaining training Y: {3}\n\
test X: {4}\n\
test Y: {5}".format(
    x_train1.shape,y_train1.shape,remainXTrain.shape,remainYTrain.shape,x_test.shape,y_test.shape))
# Out:
# initial training X: (10000, 32, 32, 3)
# initial training Y: (10000, 10)
# remaining training X: (40000, 32, 32, 3)
# remaining training Y: (40000, 10)
# test X: (10000, 32, 32, 3)
# test Y: (10000, 10)

# %%
labels = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]

# %% [markdown]
# ## Define the CNN model in Keras

# %%
# optimization and compile
def compileModel(model, lr=0.001, decay=1e-6):
    opt = keras.optimizers.adam(lr=lr, decay=decay)

    model.compile(loss='categorical_crossentropy',
                  optimizer=opt,
                  metrics=['accuracy'])
    
    return model

# %%
# define layers
def getModel(loadModel=False, modelFilePath="", lr=0.001, decay=1e-6):
    model = Sequential()
    model.add(Conv2D(64, (3, 3), padding='same', input_shape=x_train.shape[1:]))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(128, (3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(Conv2D(128, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    
    model.add(Flatten())
    model.add(Dense(1024))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes))
    model.add(Activation('softmax'))
    
    model = compileModel(model)
    
    # load model weights if specified
    if loadModel == True:
        model.load_weights(modelFilePath)
    
    return model

# %%
# get the newest model file
def getNewestModel(dirname=saveDir):
    import os
    from glob import glob
    target = os.path.join(dirname, '*')
    files = [(f, os.path.getmtime(f)) for f in glob(target)]
    if len(files) == 0:
        return getModel()
    else:
        newestModel = sorted(files, key=lambda files: files[1])[-1]
        return getModel(True, newestModel[0])

# %%
# get the CNN model
model = getModel()

# %%
# train the model
def trainModel(model, xTrain, yTrain, xTest, yTest, batch_size=50, epochs=100, patience=1):
    es_cb = EarlyStopping(monitor='val_loss', patience=patience, verbose=1, mode='auto')
    chkpt = os.path.join(saveDir, 'Cifar10_.{epoch:02d}-{loss:.2f}-{val_loss:.2f}.hdf5')
    cp_cb = ModelCheckpoint(filepath = chkpt, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

    # train
    model.fit(xTrain, yTrain,
              batch_size=batch_size,
              epochs=epochs,
              verbose=0,
              validation_data=(xTest, yTest),
              callbacks=[es_cb, cp_cb],
              shuffle=True)
    return model

# %% [markdown]
# ### Training the model for the initial dataset

# %%
# run training on the initial dataset

# model = trainModel(model, x_train1, y_train1, x_test, y_test, patience=2)

# %%
# use the pre-trained model, with 65% accuracy on test data
# model = getNewestModel()
model.load_weights("./cifar10/Cifar10_.01-0.75-1.03.hdf5")

# %%
# define evaluation method
def evaluate(model, xTest, yTest, display=False):
    # only shows loss and accuracy
    if display == False:
        ev = model.evaluate(xTest, yTest, verbose=0)
        return ev
    # shows confusion matrix, classification report and accuracy score
    else:
        import pandas as pd
        import seaborn as sn
        import matplotlib.pyplot as plt
        from sklearn.metrics import confusion_matrix
        from sklearn.metrics import classification_report, accuracy_score

        def toNum(y):
            yNum = []
            for x in y:
                yNum.append(x.argmax())
            return np.array(yNum)

        # visualize confusion matrix on heat map
        def print_cmx(y_true, y_pred):
            labels = sorted(list(set(y_true)))
            cmx_data = confusion_matrix(y_true, y_pred, labels=labels)

            df_cmx = pd.DataFrame(cmx_data, index=labels, columns=labels)

            plt.figure(figsize = (10,7))
            sn.heatmap(df_cmx, annot=True)
            plt.show()

        # reshape testing target to fit to scikit-learn metric form
        y_testPred = model.predict(xTest)
        y_testP = toNum(y_testPred)
        y_true = toNum(yTest)

        # get confusion matrix, classification report and accuracy score
        print_cmx(y_true, y_testP)
        print(classification_report(y_true, y_testP))
        print("Accuracy: {0}".format(accuracy_score(y_true, y_testP)))

# %%
# evaluate the initial test dataset
evaluate(model, x_test, y_test, display=True)
# Out:
#              precision    recall  f1-score   support
#
#           0       0.61      0.77      0.68      1000
#           1       0.74      0.84      0.79      1000
#           2       0.51      0.53      0.52      1000
#           3       0.52      0.33      0.40      1000
#           4       0.58      0.57      0.58      1000
#           5       0.60      0.54      0.57      1000
#           6       0.69      0.75      0.72      1000
#           7       0.79      0.65      0.71      1000
#           8       0.73      0.77      0.74      1000
#           9       0.74      0.77      0.75      1000
#
# avg / total       0.65      0.65      0.65     10000
#
# Accuracy: 0.6537

# %%
# record the loss and accuracy
evalHistory = []
evalHistory.append(evaluate(model, x_test, y_test, display=False))
print(evalHistory[-1])
# Out:
# [1.0257026025772096, 0.65369999999999995]

# %% [markdown]
# ## Now let's use the trained model for semi-supervised learning

# %%
# get a list of high probability inference
def getHighProb(proba, bound):
    ls = []
    for i in range(len(proba)):
        for p in range(len(proba[i])):
            if proba[i,p] > bound:
                ls.append([i,p])
    return ls

# %%
# concatenate initial training data with high probability inference, removing them from remaining data
def concatHighProbData(proba, remainX, remainY, xTrain, yTrain, bound=0.99):
    hp = getHighProb(proba, bound)
    print("number of data with probability higher than {0}: {1}".format(bound,len(hp)))
    
    nhp = np.array(hp)
    xAdd = remainX[nhp[:,0]]
    yAdd = np.array([nhp[:,1]]).T
    yAdd = keras.utils.to_categorical(yAdd, num_classes)
    yActual = remainY[nhp[:,0]]
    print("x shape to be added: {0}\ny shape to be added: {1}".format(xAdd.shape, yAdd.shape))
    
    NewXTrain = np.vstack((xTrain, xAdd))
    NewYTrain = np.vstack((yTrain, yAdd))
    print("new training data:\n\tx: {0}\n\ty: {1}".format(NewXTrain.shape, NewYTrain.shape))
    
    remainX2 = np.delete(remainX, nhp[:,0], axis=0)
    remainY2 = np.delete(remainY, nhp[:,0], axis=0)
    print("remaining data:\n\tx: {0}\n\ty: {1}".format(remainX2.shape, remainY2.shape))
    
    yEval = [[yActual[i],yAdd[i]] for i in range(len(yAdd))]
    
    return remainX2, remainY2, NewXTrain, NewYTrain, yEval

# %%
def getError(yEval):
    errLabel = [0]*10
    for i in range(len(yEval)):
        if False in (yEval[i][0] == yEval[i][1]):
            errLabel[np.argmax(yEval[i][0]-yEval[i][1])] += 1
    return errLabel

# %%
# get new training data
proba = model.predict_proba(remainXTrain, verbose=0)
remainXTrain, remainYTrain, x_train2, y_train2, yEval= concatHighProbData(proba, 
                                                                          remainXTrain, 
                                                                          remainYTrain, 
                                                                          x_train1, 
                                                                          y_train1, 
                                                                          0.9999)
errPred = getError(yEval)
# Out:
# number of data with probability higher than 0.9999: 611
# x shape to be added: (611, 32, 32, 3)
# y shape to be added: (611, 10)
# new training data:
# 	x: (10611, 32, 32, 3)
# 	y: (10611, 10)
# remaining data:
# 	x: (39389, 32, 32, 3)
# 	y: (39389, 10)

# %%
# retrain the model
model = trainModel(model, x_train2, y_train2, x_test, y_test)
# Out:
# Epoch 00001: val_loss improved from inf to 1.00156, saving model to ./cifar10/semi/Cifar10_.01-0.59-1.00.hdf5
# Epoch 00002: val_loss did not improve
# Epoch 00002: early stopping

# %%
# load the newest checkpoint model to get the best accuracy one
model = getNewestModel()

# %%
# evaluate with the initial test dataset
evaluate(model, x_test, y_test, display=True)
# Out:
#              precision    recall  f1-score   support
#
#           0       0.72      0.68      0.70      1000
#           1       0.82      0.82      0.82      1000
#           2       0.56      0.50      0.53      1000
#           3       0.45      0.37      0.41      1000
#           4       0.62      0.56      0.58      1000
#           5       0.48      0.69      0.57      1000
#           6       0.76      0.71      0.73      1000
#           7       0.65      0.78      0.70      1000
#           8       0.81      0.75      0.78      1000
#           9       0.82      0.76      0.79      1000
#
# avg / total       0.67      0.66      0.66     10000
#
# Accuracy: 0.6613

# %%
# record the loss and accuracy
evalHistory.append(evaluate(model, x_test, y_test, display=False))
print(evalHistory[-1])
# Out:
# [1.0015581752777099, 0.6613]

# %% [markdown]
# ### repeat semi-supervised learning for 10 times

# %%
for i in range(10):
    proba = model.predict_proba(remainXTrain, verbose=0)
    remainXTrain, remainYTrain, x_train2, y_train2, yEval = concatHighProbData(proba, 
                                                                               remainXTrain, 
                                                                               remainYTrain, 
                                                                               x_train2, 
                                                                               y_train2, 
                                                                               0.9999)
    errPred2 = getError(yEval)
    errPred = [errPred2[i]+errPred[i] for i in range(len(errPred))]
    model = trainModel(model, x_train2, y_train2, x_test, y_test)
    model = getNewestModel()
    evalHistory.append(evaluate(model, x_test, y_test, display=False))
    print("\nAfter Iter: {0}\n\tLoss and Acc: {1}\n".format(i,evalHistory[-1]))
# Out:
# number of data with probability higher than 0.9999: 190
# x shape to be added: (190, 32, 32, 3)
# y shape to be added: (190, 10)
# new training data:
# 	x: (10801, 32, 32, 3)
# 	y: (10801, 10)
# remaining data:
# 	x: (39199, 32, 32, 3)
# 	y: (39199, 10)
# Epoch 00001: val_loss improved from inf to 1.01151, saving model to ./cifar10/semi/Cifar10_.01-0.54-1.01.hdf5
# Epoch 00002: val_loss did not improve
# Epoch 00002: early stopping
#
# After Iter: 0
# 	Loss and Acc: [1.0115121746063231, 0.66769999999999996]
#
# number of data with probability higher than 0.9999: 657
# x shape to be added: (657, 32, 32, 3)
# y shape to be added: (657, 10)
# new training data:
# 	x: (11458, 32, 32, 3)
# 	y: (11458, 10)
# remaining data:
# 	x: (38542, 32, 32, 3)
# 	y: (38542, 10)
# Epoch 00001: val_loss improved from inf to 1.08351, saving model to ./cifar10/semi/Cifar10_.01-0.47-1.08.hdf5
# Epoch 00002: val_loss improved from 1.08351 to 1.04959, saving model to ./cifar10/semi/Cifar10_.02-0.41-1.05.hdf5
# Epoch 00003: val_loss did not improve
# Epoch 00003: early stopping
#
# After Iter: 1
# 	Loss and Acc: [1.0495927443504334, 0.66759999999999997]
#
# number of data with probability higher than 0.9999: 1243
# x shape to be added: (1243, 32, 32, 3)
# y shape to be added: (1243, 10)
# new training data:
# 	x: (12701, 32, 32, 3)
# 	y: (12701, 10)
# remaining data:
# 	x: (37299, 32, 32, 3)
# 	y: (37299, 10)
# Epoch 00001: val_loss improved from inf to 1.20949, saving model to ./cifar10/semi/Cifar10_.01-0.37-1.21.hdf5
# Epoch 00002: val_loss improved from 1.20949 to 1.03809, saving model to ./cifar10/semi/Cifar10_.02-0.38-1.04.hdf5
# Epoch 00003: val_loss did not improve
# Epoch 00003: early stopping
#
# After Iter: 2
# 	Loss and Acc: [1.0380887203216553, 0.66820000000000002]
#
# number of data with probability higher than 0.9999: 608
# x shape to be added: (608, 32, 32, 3)
# y shape to be added: (608, 10)
# new training data:
# 	x: (13309, 32, 32, 3)
# 	y: (13309, 10)
# remaining data:
# 	x: (36691, 32, 32, 3)
# 	y: (36691, 10)
# Epoch 00001: val_loss improved from inf to 1.19005, saving model to ./cifar10/semi/Cifar10_.01-0.31-1.19.hdf5
# Epoch 00002: val_loss improved from 1.19005 to 1.13493, saving model to ./cifar10/semi/Cifar10_.02-0.28-1.13.hdf5
# Epoch 00003: val_loss did not improve
# Epoch 00003: early stopping
#
# After Iter: 3
# 	Loss and Acc: [1.134932650756836, 0.67090000000000005]
#
# number of data with probability higher than 0.9999: 1223
# x shape to be added: (1223, 32, 32, 3)
# y shape to be added: (1223, 10)
# new training data:
# 	x: (14532, 32, 32, 3)
# 	y: (14532, 10)
# remaining data:
# 	x: (35468, 32, 32, 3)
# 	y: (35468, 10)
# Epoch 00001: val_loss improved from inf to 1.15364, saving model to ./cifar10/semi/Cifar10_.01-0.27-1.15.hdf5
# Epoch 00002: val_loss did not improve
# Epoch 00002: early stopping
#
# After Iter: 4
# 	Loss and Acc: [1.1536360531806946, 0.67749999999999999]
#
# number of data with probability higher than 0.9999: 866
# x shape to be added: (866, 32, 32, 3)
# y shape to be added: (866, 10)
# new training data:
# 	x: (15398, 32, 32, 3)
# 	y: (15398, 10)
# remaining data:
# 	x: (34602, 32, 32, 3)
# 	y: (34602, 10)
# Epoch 00001: val_loss improved from inf to 1.22541, saving model to ./cifar10/semi/Cifar10_.01-0.23-1.23.hdf5
# Epoch 00002: val_loss improved from 1.22541 to 1.21082, saving model to ./cifar10/semi/Cifar10_.02-0.21-1.21.hdf5
# Epoch 00003: val_loss did not improve
# Epoch 00003: early stopping
#
# After Iter: 5
# 	Loss and Acc: [1.2108178945541381, 0.6704]
#
# number of data with probability higher than 0.9999: 1000
# x shape to be added: (1000, 32, 32, 3)
# y shape to be added: (1000, 10)
# new training data:
# 	x: (16398, 32, 32, 3)
# 	y: (16398, 10)
# remaining data:
# 	x: (33602, 32, 32, 3)
# 	y: (33602, 10)
# Epoch 00001: val_loss improved from inf to 1.22822, saving model to ./cifar10/semi/Cifar10_.01-0.21-1.23.hdf5
# Epoch 00002: val_loss did not improve
# Epoch 00002: early stopping
#
# After Iter: 6
# 	Loss and Acc: [1.2282215538978576, 0.66869999999999996]
#
# number of data with probability higher than 0.9999: 576
# x shape to be added: (576, 32, 32, 3)
# y shape to be added: (576, 10)
# new training data:
# 	x: (16974, 32, 32, 3)
# 	y: (16974, 10)
# remaining data:
# 	x: (33026, 32, 32, 3)
# 	y: (33026, 10)
# Epoch 00001: val_loss improved from inf to 1.24087, saving model to ./cifar10/semi/Cifar10_.01-0.20-1.24.hdf5
# Epoch 00002: val_loss did not improve
# Epoch 00002: early stopping
#
# After Iter: 7
# 	Loss and Acc: [1.2408743978500367, 0.68320000000000003]
#
# number of data with probability higher than 0.9999: 1316
# x shape to be added: (1316, 32, 32, 3)
# y shape to be added: (1316, 10)
# new training data:
# 	x: (18290, 32, 32, 3)
# 	y: (18290, 10)
# remaining data:
# 	x: (31710, 32, 32, 3)
# 	y: (31710, 10)
# Epoch 00001: val_loss improved from inf to 1.32115, saving model to ./cifar10/semi/Cifar10_.01-0.19-1.32.hdf5
# Epoch 00002: val_loss improved from 1.32115 to 1.17577, saving model to ./cifar10/semi/Cifar10_.02-0.17-1.18.hdf5
# Epoch 00003: val_loss did not improve
# Epoch 00003: early stopping
#
# After Iter: 8
# 	Loss and Acc: [1.1757713478088379, 0.68759999999999999]
#
# number of data with probability higher than 0.9999: 581
# x shape to be added: (581, 32, 32, 3)
# y shape to be added: (581, 10)
# new training data:
# 	x: (18871, 32, 32, 3)
# 	y: (18871, 10)
# remaining data:
# 	x: (31129, 32, 32, 3)
# 	y: (31129, 10)
# Epoch 00001: val_loss improved from inf to 1.28441, saving model to ./cifar10/semi/Cifar10_.01-0.18-1.28.hdf5
# Epoch 00002: val_loss did not improve
# Epoch 00002: early stopping
#
# After Iter: 9
# 	Loss and Acc: [1.2844130910873413, 0.68259999999999998]

# %%
# evaluate the initial test dataset
evaluate(model, x_test, y_test, display=True)
# Out:
#              precision    recall  f1-score   support
#
#           0       0.77      0.62      0.69      1000
#           1       0.84      0.83      0.84      1000
#           2       0.63      0.46      0.53      1000
#           3       0.50      0.42      0.46      1000
#           4       0.57      0.69      0.63      1000
#           5       0.56      0.62      0.59      1000
#           6       0.67      0.84      0.75      1000
#           7       0.71      0.77      0.74      1000
#           8       0.76      0.83      0.80      1000
#           9       0.84      0.73      0.78      1000
#
# avg / total       0.69      0.68      0.68     10000
#
# Accuracy: 0.6826

# %% [markdown]
# ## wrap up the semi-supervised learning

# %%
# show remaining data in each label
remainLabel = [0]*10
for y in remainYTrain:
    remainLabel[np.argmax(y)] += 1
remainLabel
# Out:
# [3110, 1950, 3737, 3945, 3855, 3802, 2978, 2754, 2455, 2543]

# %%
# show data in each label used on training
usedLabels = [5000-i for i in remainLabel]
usedLabels
# Out:
# [1890, 3050, 1263, 1055, 1145, 1198, 2022, 2246, 2545, 2457]

# %%
# show graph for the data used, remaining and number of errors with high probability prediction on each label
import matplotlib.pyplot as plt
fig, ax1 = plt.subplots(figsize = (10,7))
ax2 = ax1.twinx()

w = 0.4
l1 = list(range(10))

ax1.bar(l1, usedLabels, align='center', color="blue", width=w, label='trained')
ax1.bar(l1, remainLabel, align='center', color="green", width=w, label='remaining', bottom=usedLabels)
ax2.plot(errPred,  color="red", label='high probability but wrong')
ax1.legend(loc="lower left")
ax2.legend(loc="lower right")
ax1.set_xlabel("Labels")
ax1.set_ylabel("Data trained and remaining")
ax2.set_ylabel("High probability but wrong")

plt.xticks(l1, labels)
plt.show()

# %%
for i in range(10):
    print("{0}:\t{1}% wrong label added".format(labels[i], round((errPred[i]/usedLabels[i])*100, 3)))
# Out:
# airplane:	2.063% wrong label added
# automobile:	0.984% wrong label added
# bird:	3.088% wrong label added
# cat:	1.706% wrong label added
# deer:	1.834% wrong label added
# dog:	1.252% wrong label added
# frog:	0.049% wrong label added
# horse:	0.579% wrong label added
# ship:	1.336% wrong label added
# truck:	2.279% wrong label added

# %%
# show evaluation history
npeh = np.array(evalHistory)
fig, ax1 = plt.subplots(figsize=(10,7))
epochHis = list(range(12))
ax1.plot(epochHis, npeh[:,0], "b", label="Loss")
ax1.set_xlabel("Epochs")
ax1.set_ylabel("Loss")
ax1.legend()

ax2 = ax1.twinx()
ax2.plot(epochHis, npeh[:,1], "r", label="Accuracy")
ax2.set_ylabel("Accuracy")
ax2.legend()

plt.show()
